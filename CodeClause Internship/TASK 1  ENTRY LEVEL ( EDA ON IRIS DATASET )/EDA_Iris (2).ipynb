# %% [markdown]
# # Iris Dataset Exploratory Data Analysis (EDA)

# %% [markdown]
# ### 1. Import Relevant Libraries/Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### 2. Load Dataset and Create Dataframe

# %%
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### 3. Dataset Exploration

# %%
# dataframe information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# statistics behind dataframe
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# columns in dataframe
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# 'Id' column is not useful for our EDA. So, let's drop it from dataframe
df = df.drop('Id', axis=1)
df.head(2)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa

# %%
# shape of the dataframe
df.shape
# Out:
# (150, 5)

# %%
# check null or missing value in dataframe
df.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ##### Conclusion of Data Exploration:
# 1. Dataset contain both numeric as well as object (char) datatype columns.
# 2. Dataset contain total 6 columns, 'Id' is not useful so we drop that from dataframe.
# 3. Dataset contain total 150 records.
# 4. Dataset doesn't have missing values.
# 5. Stats behind dataset is pretty much good. But, we can understand more during visualization or EDA.

# %% [markdown]
# ### 4. Exploratory Data Analysis (EDA) or Data Visualization

# %%
sns.pairplot(data=df, hue='Species')
plt.show()

# %%
# feature distribution
plt.figure(figsize=(15, 10))
plt.title('Feature Distribution using Violin Plot')
plt.subplot(2, 2, 1)
sns.violinplot(x='Species', y='SepalLengthCm', data=df, hue='Species')
plt.subplot(2, 2, 2)
sns.violinplot(x='Species', y='SepalWidthCm', data=df, hue='Species')
plt.subplot(2, 2, 3)
sns.violinplot(x='Species', y='PetalLengthCm', data=df, hue='Species')
plt.subplot(2, 2, 4)
sns.violinplot(x='Species', y='PetalWidthCm', data=df, hue='Species')
plt.tight_layout()
plt.show()

# %%
# Histogram distribution of features
plt.figure(figsize=(15, 10))
plt.title('Feature Distribution using Histogram')
plt.subplot(2, 2, 1)
sns.histplot(df['SepalLengthCm'], kde=True, bins=30)
plt.subplot(2, 2, 2)
sns.histplot(df['SepalWidthCm'], kde=True, bins=30)
plt.subplot(2, 2, 3)
sns.histplot(df['PetalLengthCm'], kde=True, bins=30)
plt.subplot(2, 2, 4)
sns.histplot(df['PetalWidthCm'], kde=True, bins=30)
plt.tight_layout()
plt.show()

# %%
# Correlation matrix
df_corr = df.drop('Species', axis=1)
plt.figure(figsize=(10, 5))
plt.title('Correlation Matrix')
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
# Scatter Plot of features
plt.figure(figsize=(15, 12))
plt.title('Scatter Plot of Features for Sepal Length and Sepal Width')

plt.subplot(1, 2, 1)
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=df)

plt.subplot(1, 2, 2)
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=df)

plt.tight_layout()
plt.show()

# %%
# KDE Plot of features
plt.figure(figsize=(15, 12))
plt.title('KDE Plot of Features for Iris-versicolor')
versicolor = df[df['Species']=='Iris-versicolor']

plt.subplot(1, 2, 1)
sns.kdeplot(x=versicolor['SepalWidthCm'],y=versicolor['SepalLengthCm'],cmap='plasma',shade=True)

plt.subplot(1, 2, 2)
sns.kdeplot(x=versicolor['PetalWidthCm'],y=versicolor['PetalLengthCm'],cmap='plasma',shade=True)

plt.tight_layout()
plt.show()

# %%
# KDE Plot of features
plt.figure(figsize=(15, 12))
plt.title('KDE Plot of Features for Sepal Length and Sepal Width for Iris-virginica')
virginica = df[df['Species']=='Iris-virginica']

plt.subplot(1, 2, 1)
sns.kdeplot(x=virginica['SepalWidthCm'],y=virginica['SepalLengthCm'],cmap='plasma',shade=True)

plt.subplot(1, 2, 2)
sns.kdeplot(x=virginica['PetalWidthCm'],y=virginica['PetalLengthCm'],cmap='plasma',shade=True)

plt.tight_layout()
plt.show()

# %%
# KDE Plot of features
plt.figure(figsize=(15, 12))
plt.title('KDE Plot of Features for Sepal Length and Sepal Width for Iris-setosa')
setosa = df[df['Species']=='Iris-setosa']

plt.subplot(1, 2, 1)
sns.kdeplot(x=setosa['SepalWidthCm'],y=setosa['SepalLengthCm'],cmap='plasma',shade=True)

plt.subplot(1, 2, 2)
sns.kdeplot(x=setosa['PetalWidthCm'],y=setosa['PetalLengthCm'],cmap='plasma',shade=True)

plt.tight_layout()
plt.show()

# %%
# Box Plot of features
plt.figure(figsize=(15, 10))
plt.title('Box Plot of Features')
plt.subplot(2, 2, 1)
sns.boxplot(x='Species', y='SepalLengthCm', data=df, hue='Species')
plt.subplot(2, 2, 2)
sns.boxplot(x='Species', y='SepalWidthCm', data=df, hue='Species')
plt.subplot(2, 2, 3)
sns.boxplot(x='Species', y='PetalLengthCm', data=df, hue='Species')
plt.subplot(2, 2, 4)
sns.boxplot(x='Species', y='PetalWidthCm', data=df, hue='Species')
plt.tight_layout()
plt.show()

# %%
# Swarm Plot of features
plt.figure(figsize=(15, 10))
plt.title('Swarm Plot of Features')
plt.subplot(2, 2, 1)
sns.swarmplot(x='Species', y='SepalLengthCm', data=df, hue='Species')
plt.subplot(2, 2, 2)
sns.swarmplot(x='Species', y='SepalWidthCm', data=df, hue='Species')
plt.subplot(2, 2, 3)
sns.swarmplot(x='Species', y='PetalLengthCm', data=df, hue='Species')
plt.subplot(2, 2, 4)
sns.swarmplot(x='Species', y='PetalWidthCm', data=df, hue='Species')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Conclusions: EDA
# 1. Iris-setosa has smaller sepal length and width compared to other two species.
# 2. Iris-setosa has smaller petal length and width compared to other two species.
# 3. Iris-virginica has larger sepal length and width compared to other two species.
# 4. Iris-virginica has larger petal length and width compared to other two species.
# 5. Iris-versicolor has average sepal length and width compared to other two species.
# 6. Iris-versicolor has average petal length and width compared to other two species.
# 7. Sepal length and width are not much correlated.
# 8. Petal length and width are highly correlated.
# 9. Sepal length and width are not much correlated for Iris-versicolor.
# 10. Petal length and width are highly correlated for Iris-versicolor.
# 11. Sepal length and width are not much correlated for Iris-virginica.
# 12. Petal length and width are highly correlated for Iris-virginica.
# 13. Sepal length and width are not much correlated for Iris-setosa.
# 14. Petal length and width are highly correlated for Iris-setosa.
# 15. Sepal length and width are not much correlated for Iris-setosa.
# 16. Petal length and width are highly correlated for Iris-setosa.
